# %%
from pyddm import Model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from utils import *
from pyddm.models import DriftConstant, NoiseConstant, BoundConstant, OverlayNonDecision, ICPointSourceCenter, OverlayChain, OverlayPoissonMixture
from pyddm.functions import fit_adjust_model, display_model
from pyddm import Fittable, Fitted, Sample
from pyddm.models import LossRobustBIC, LossRobustLikelihood
import scipy.stats as stat
import pyddm.plot
import pyddm as ddm

# %%
files = os.listdir('data/')
comb_data = pd.concat([extract_data(fname) for fname in files]).reset_index(drop=True)
comb_data['bumps_'] = '0_noisy'
comb_data.loc[comb_data['bumps'] == 'single', 'bumps_'] = '1_single'
comb_data.loc[comb_data['bumps'] == 'center', 'bumps_'] = '1_center'
comb_data = comb_data.loc[comb_data['rt'] < 10].reset_index(drop = True)

# %%
samp = Sample.from_pandas_dataframe(comb_data, rt_column_name='rt', choice_column_name='response')

# %%
model_fit = Model(name='Simple model (fitted)',
                  drift=DriftConstant(drift=Fittable(minval=0, maxval=4)),
                  noise=NoiseConstant(noise=Fittable(minval=.1, maxval=4)),
                  bound=BoundConstant(B=Fittable(minval=.1, maxval=5)),
                  overlay=OverlayNonDecision(nondectime=Fittable(minval=0, maxval=1)),
                  dx=.001, dt=.005, T_dur=10, 
                     )

# %%
fit_model = fit_adjust_model(sample=samp, model=model_fit, verbose=False, lossfunction=LossRobustLikelihood)
# Out:
# Warning: Renormalizing probability density from 1.0115010427802626 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model spefication.
# Info: Params [1.01526093 2.13940753 2.94178907 0.00336944] gave 27235.248099816377

# %%
pyddm.plot.plot_fit_diagnostics(model=fit_model, sample=samp)

# %%
comb_data
# Out:
#        participant  means  direction   bumps  diff_dir  trials.thisN  \
# 0          25353.0   64.0        1.0  single       1.0           0.0
# 1          25353.0   48.0        1.0   noisy      -1.0           1.0
# 2          25353.0   53.0        1.0   noisy      -1.0           2.0
# 3          25353.0   64.0       -1.0  center      -1.0           3.0
# 4          25353.0   60.0        1.0  center       1.0           4.0
# ...            ...    ...        ...     ...       ...           ...
# 11434     908388.0   60.0        1.0   noisy      -1.0         285.0
# 11435     908388.0   49.0        1.0  single      -1.0         286.0
# 11436     908388.0   38.0       -1.0  single      -1.0         287.0
# 11437     908388.0   62.0       -1.0  center      -1.0         288.0
# 11438     908388.0   43.0       -1.0  single       1.0         289.0
#
#        difference incorrect choice key_resp        rt   cond  accuracy  \
# 0             8.0             left     left  3.881548  chart     False
# 1            -6.0            right    right  7.387671  chart     False
# 2           -10.0             left    right  6.337773  chart      True
# 3            -8.0             left    right  3.151569  chart      True
# 4             8.0             left    right  5.806216  chart      True
# ...           ...              ...      ...       ...    ...       ...
# 11434        -8.0             left     left  2.442362  chart     False
# 11435       -12.0            right     left  0.798230  chart      True
# 11436       -11.0             left    right  0.681007  chart      True
# 11437       -12.0            right     left  0.802785  chart      True
# 11438        12.0            right     left  0.887175  chart      True
#
#        response    bumps_
# 0            -1  1_single
# 1            -1   0_noisy
# 2             1   0_noisy
# 3             1  1_center
# 4             1  1_center
# ...         ...       ...
# 11434        -1   0_noisy
# 11435         1  1_single
# 11436         1  1_single
# 11437         1  1_center
# 11438         1  1_single
#
# [11439 rows x 14 columns]

# %% [markdown]
# # Varying parameters

# %%
class DriftDirection(ddm.models.Drift):
    name = "Drift depends linearly on Direction"
    required_parameters = ["driftdir", "driftbumps"] # <-- Parameters we want to include in the model
    required_conditions = ["direction", "bumps_"] # <-- Task parameters ("conditions"). Should be the same name as in the sample.
    
    # We must always define the get_drift function, which is used to compute the instantaneous value of drift.
    def get_drift(self, conditions, **kwargs):
        return self.driftdir * conditions['direction'] + self.driftbumps * conditions['bumps_']

# %%
model_dd = Model(name='Drift varies with direction',
                 drift=DriftDirection(driftdir=Fittable(minval=-10, maxval=20),
                                     driftbumps=Fittable(minval = -10, maxval = 20)),
                 noise=NoiseConstant(noise=Fittable(minval=.1, maxval=4)),
                 bound=BoundConstant(B=Fittable(minval=.1, maxval=10)),
                 # Since we can only have one overlay, we use
                 # OverlayChain to string together multiple overlays.
                 # They are applied sequentially in order.  OverlayNonDecision
                 # implements a non-decision time by shifting the
                 # resulting distribution of response times by
                 # `nondectime` seconds.
                 overlay=OverlayChain(overlays=[OverlayNonDecision(nondectime=Fittable(minval=0, maxval=.4)),
                                                OverlayPoissonMixture(pmixturecoef=.02,
                                                                      rate=1)]),
                 dx=.001, dt=.01, T_dur=10)

# Fitting this will also be fast because PyDDM can automatically
# determine that DriftCoherence will allow an analytical solution.
fit_model_rs = fit_adjust_model(sample=samp, model=model_dd, verbose=False, lossfunction=LossRobustLikelihood)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Anaconda3\envs\datavis\Lib\site-packages\scipy\optimize\_differentialevolution.py:1122, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1121 try:
# -> 1122     calc_energies = list(
#    1123         self._mapwrapper(self.func, parameters_pop[0:S])
#    1124     )
#    1125     calc_energies = np.squeeze(calc_energies)
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\scipy\_lib\_util.py:372, in _FunctionWrapper.__call__(self, x)
#     371 def __call__(self, x):
# --> 372     return self.f(x, *self.args)
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\functions.py:350, in fit_adjust_model.<locals>._fit_model(xs)
#     349     s(m, x)
# --> 350 lossf = lf.loss(m)
#     351 if verbose:
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\paranoid\decorators.py:114, in _wrap.<locals>._decorated(*args, **kwargs)
#     113 if Settings.get("enabled", function=func) == False:
# --> 114     return func(*args, **kwargs)
#     115 # We only run this function once for performance reasons, and
#     116 # then pass it as an argument to each check function.
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\models\loss.py:166, in LossLikelihood.loss(self, model)
#     165 assert model.dt == self.dt and model.T_dur == self.T_dur
# --> 166 sols = self.cache_by_conditions(model)
#     167 loglikelihood = 0
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\models\loss.py:93, in LossFunction.cache_by_conditions(self, model)
#      92 from ..functions import solve_all_conditions
# ---> 93 return solve_all_conditions(model, sample=self.sample, method=self.method)
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\functions.py:523, in solve_all_conditions(model, sample, condition_combinations, method)
#     522 for c in conds:
# --> 523     cache[frozenset(c.items())] = meth(conditions=c)
#     524 return cache
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\paranoid\decorators.py:114, in _wrap.<locals>._decorated(*args, **kwargs)
#     113 if Settings.get("enabled", function=func) == False:
# --> 114     return func(*args, **kwargs)
#     115 # We only run this function once for performance reasons, and
#     116 # then pass it as an argument to each check function.
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\model.py:546, in Model.solve(self, conditions, return_evolution, force_python)
#     545 if self.has_analytical_solution() and return_evolution is False:
# --> 546     return self.solve_analytical(conditions=conditions)
#     547 elif isinstance(self.get_dependence("bound"), BoundConstant) and return_evolution is False and (force_python or not HAS_CSOLVE):
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\paranoid\decorators.py:114, in _wrap.<locals>._decorated(*args, **kwargs)
#     113 if Settings.get("enabled", function=func) == False:
# --> 114     return func(*args, **kwargs)
#     115 # We only run this function once for performance reasons, and
#     116 # then pass it as an argument to each check function.
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\model.py:586, in Model.solve_analytical(self, conditions, force_python)
#     585 else: # Constant bound DDM
# --> 586     anal_pdf_choice_upper, anal_pdf_choice_lower = analytic_ddm(self.get_dependence("drift").get_drift(t=0, x=0, conditions=conditions),
#     587                                                 self.get_dependence("noise").get_noise(t=0, x=0, conditions=conditions),
#     588                                                self.get_dependence("bound").get_bound(t=0, x=0, conditions=conditions),
#     589                                                self.t_domain(), shift,
#     590                                                force_python=force_python)
#     592 ## Remove some abnormalities such as NaN due to trivial reasons.
#
# Cell In[26], line 8, in DriftDirection.get_drift(self, conditions, **kwargs)
#       7 def get_drift(self, conditions, **kwargs):
# ----> 8     return self.driftdir * conditions['direction'] + self.driftbumps * conditions['bumps_']
#
# TypeError: can't multiply sequence by non-int of type 'Fitted'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 19
#       1 model_dd = Model(name='Drift varies with direction',
#       2                  drift=DriftDirection(driftdir=Fittable(minval=-10, maxval=20),
#       3                                      driftbumps=Fittable(minval = -10, maxval = 20)),
#    (...)
#      14                                                                       rate=1)]),
#      15                  dx=.001, dt=.01, T_dur=10)
#      17 # Fitting this will also be fast because PyDDM can automatically
#      18 # determine that DriftCoherence will allow an analytical solution.
# ---> 19 fit_model_rs = fit_adjust_model(sample=samp, model=model_dd, verbose=False, lossfunction=LossRobustLikelihood)
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\pyddm\functions.py:368, in fit_adjust_model(sample, model, fitparams, fitting_method, lossfunction, verify, method, verbose)
#     366     if "disp" not in fitparams.keys():
#     367         fitparams["disp"] = verbose
# --> 368     x_fit = differential_evolution(_fit_model, constraints, **fitparams)
#     369 elif fitting_method == "hillclimb":
#     370     x_fit = evolution_strategy(_fit_model, x_0, **fitparams)
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\scipy\optimize\_differentialevolution.py:397, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     380 # using a context manager means that any created Pool objects are
#     381 # cleared up.
#     382 with DifferentialEvolutionSolver(func, bounds, args=args,
#     383                                  strategy=strategy,
#     384                                  maxiter=maxiter,
#    (...)
#     395                                  integrality=integrality,
#     396                                  vectorized=vectorized) as solver:
# --> 397     ret = solver.solve()
#     399 return ret
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\scipy\optimize\_differentialevolution.py:989, in DifferentialEvolutionSolver.solve(self)
#     984     self.feasible, self.constraint_violation = (
#     985         self._calculate_population_feasibilities(self.population))
#     987     # only work out population energies for feasible solutions
#     988     self.population_energies[self.feasible] = (
# --> 989         self._calculate_population_energies(
#     990             self.population[self.feasible]))
#     992     self._promote_lowest_energy()
#     994 # do the optimization.
#
# File ~\Anaconda3\envs\datavis\Lib\site-packages\scipy\optimize\_differentialevolution.py:1129, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1125     calc_energies = np.squeeze(calc_energies)
#    1126 except (TypeError, ValueError) as e:
#    1127     # wrong number of arguments for _mapwrapper
#    1128     # or wrong length returned from the mapper
# -> 1129     raise RuntimeError(
#    1130         "The map-like callable must be of the form f(func, iterable), "
#    1131         "returning a sequence of numbers the same length as 'iterable'"
#    1132     ) from e
#    1134 if calc_energies.size != S:
#    1135     if self.vectorized:
#
# RuntimeError: The map-like callable must be of the form f(func, iterable), returning a sequence of numbers the same length as 'iterable'

# %%
pyddm.plot.plot_fit_diagnostics(model=model_dd, sample=samp)

# %%
display_model(fit_model_rs)
# Out:
# Model Drift varies with direction information:
# Choices: 'correct' (upper boundary), 'error' (lower boundary)
# Drift component DriftDirection:
#     Drift depends linearly on Direction
#     Fitted parameters:
#     - driftdir: 0.295804
# Noise component NoiseConstant:
#     constant
#     Fitted parameters:
#     - noise: 3.253078
# Bound component BoundConstant:
#     constant
#     Fitted parameters:
#     - B: 3.661567
# IC component ICPointSourceCenter:
#     point_source_center
#     (No parameters)
# Overlay component OverlayChain:
#     Overlay component OverlayNonDecision:
#         Add a non-decision by shifting the histogram
#         Fitted parameters:
#         - nondectime: 0.314676
#     Overlay component OverlayPoissonMixture:
#         Poisson distribution mixture model (lapse rate)
#         Fixed parameters:
#         - pmixturecoef: 0.020000
#         - rate: 1.000000
# Fit information:
#     Loss function: Negative log likelihood
#     Loss function value: 27635.59169568367
#     Fitting method: differential_evolution
#     Solver: auto
#     Other properties:
#         - nparams: 4
#         - samplesize: 14844
#         - mess: ''
